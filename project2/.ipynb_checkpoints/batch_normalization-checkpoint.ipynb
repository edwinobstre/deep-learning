# %% [markdown]
# # Batch Normalization
#
# In this task, we implement batch normalization, which normalizes hidden layers and makes the training procedure more stable.
#
# Reference: [Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing
# Internal Covariate Shift", ICML 2015.](https://arxiv.org/abs/1502.03167)

# %%
# As usual, a bit of setup
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from data_utils import get_CIFAR10_data
from implementations.layers import batchnorm_forward

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()

# %%
# Load the (preprocessed) CIFAR10 data.
data = get_CIFAR10_data()
for k, v in data.items():
  print('%s: ' % k, v.shape)
# Out:
# X_train:  (49000, 3, 32, 32)
# y_train:  (49000,)
# X_val:  (1000, 3, 32, 32)
# y_val:  (1000,)
# X_test:  (1000, 3, 32, 32)
# y_test:  (1000,)

# %% [markdown]
# ## Batch normalization: forward
# In the file `implementations/layers.py`, implement the batch normalization forward pass in the function `batchnorm_forward`. Once you have done so, run the following to test your implementation.
#
# Referencing the paper linked to above would be helpful!

# %%
# A very simple example

xtrain = np.array([[10], [20], [30]])

xtest = np.array([[25]])


# initialize parameters for batch normalization
bn_param = {}
bn_param['mode'] = 'train'
bn_param['eps'] = 1e-4
bn_param['momentum'] = 0.95

# initialize the running mean as zero and the running variance as one 
bn_param['running_mean'] = np.zeros([1, xtrain.shape[1]])
bn_param['running_var'] = np.ones([1, xtrain.shape[1]])

# gamma and beta do not make changes to the standardization result from the first step. 
gamma = np.ones([1])
beta = np.zeros([1])

print('Before batch normalization, xtrain has ')
print_mean_std(xtrain,axis=0)

xnorm = batchnorm_forward(xtrain, gamma, beta, bn_param)

print('After batch normalization, xtrain has ')
print_mean_std(xnorm,axis=0) # The mean and std should be 0 and 1 respectively


print('After batch normalization, the running mean and the running variance are updated to')
print(bn_param['running_mean']) # should be 1.0
print(bn_param['running_var']) # should be 4.283


for iter in range(1000):
    xnorm = batchnorm_forward(xtrain, gamma, beta, bn_param)
    
print('After many iterations, the running mean and the running variance are updated to')
print(bn_param['running_mean']) # should be 20, the mean of xtrain
print(bn_param['running_var']) # should be 66.667, the variance of xtrain


# enter test mode, 
bn_param['mode'] = 'test'
xtest_norm = batchnorm_forward(xtest, gamma, beta, bn_param)

print('Before batch normalization, xtest becomes ') # should be [[0.61237198]]
print(xtest_norm)
# Out:
# Before batch normalization, xtrain has
#   means:  [20.]
#   stds:   [8.16496581]
#
# After batch normalization, xtrain has
#   means:  [0.]
#   stds:   [0.99999925]
#
# After batch normalization, the running mean and the running variance are updated to
# [[1.]]
# [[4.28333333]]
# After many iterations, the running mean and the running variance are updated to
# [[20.]]
# [[66.66666667]]
# Before batch normalization, xtest becomes
# [[0.61237198]]

# %%
# Compare with tf.layers.batch_normalization 

# Simulate the forward pass for a two-layer network
np.random.seed(15009)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)

W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)


# initialize parameters for batch normalization
bn_param = {}
bn_param['mode'] = 'train'
bn_param['eps'] = 1e-4
bn_param['momentum'] = 0.95
bn_param['running_mean'] = np.zeros([1, a.shape[1]])
bn_param['running_var'] = np.ones([1, a.shape[1]])

# random gamma and beta
gamma = np.random.rand(D3) + 1.0
beta = np.random.rand(D3)


# Setting up a tensorflow bn layer using the same set of parameters. 

tf.reset_default_graph()
tfa = tf.placeholder(tf.float32, shape=[None, a.shape[1]])

# used to control the mode
is_training = tf.placeholder_with_default(False,(),'is_training')

# the axis setting is a little strange to me. But you can understand it as that the axis is along 
# the running mean
tfa_norm = tf.layers.batch_normalization(tfa, axis=1, momentum=0.95, epsilon=bn_param['eps'],
                                         beta_initializer=tf.constant_initializer(beta), 
                                         gamma_initializer=tf.constant_initializer(gamma), 
                                         moving_mean_initializer=tf.zeros_initializer(), 
                                         moving_variance_initializer=tf.ones_initializer(), 
                                         training=is_training)

# this operation is for undating running mean and running variance. 
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

session = tf.Session()

# initialize parameters
session.run(tf.global_variables_initializer())


outputs = []
nbatch = 3
batch_size=10
                     
for ibatch in range(nbatch):
    
    # fetch the batch
    a_batch = a[ibatch * batch_size : (ibatch + 1) * batch_size]
    
    # batch normlaization with your implementation
    a_nprun = batchnorm_forward(a_batch, gamma, beta, bn_param)
    
    # batch normalization with the tensorflow layer. Also update the running mean and variance. 
    a_tfrun, _ = session.run([tfa_norm, update_ops], feed_dict={tfa: a_batch.astype(np.float32), is_training: True})
    
    print("Training batch %d: difference from the two implementations is %f" % (ibatch, rel_error(a_nprun, a_tfrun)))

    
# enterining test mode    
bn_param['mode'] = 'test'
          
for ibatch in range(nbatch):
    a_batch = a[ibatch * batch_size : (ibatch + 1) * batch_size]
    
    a_nprun = batchnorm_forward(a_batch, gamma, beta, bn_param)
    
    # run batch normalization in test mode. No need to update the running mean and variance. 
    a_tfrun = session.run(tfa_norm, feed_dict={tfa: a_batch.astype(np.float32)})

    
    print("Test batch %d: difference from the two implementations is %f" % (ibatch, rel_error(a_nprun, a_tfrun)))
# Out:
# WARNING:tensorflow:From <ipython-input-4-d9f61784a719>:41: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Training batch 0: difference from the two implementations is 0.000001
# Training batch 1: difference from the two implementations is 0.000015
# Training batch 2: difference from the two implementations is 0.000001
# Test batch 0: difference from the two implementations is 0.000000
# Test batch 1: difference from the two implementations is 0.000000
# Test batch 2: difference from the two implementations is 0.000002

# %% [markdown]
# ## Fully Connected Nets with Batch Normalization
# Now that you have a working implementation for batch normalization. Then you need to go back to your `FullyConnectedNet` in the file `implementations/fc_net.py`. Modify the implementation to add batch normalization.
#
# When the `use_bn` flag is set, the network should apply batch normalization before each ReLU nonlinearity. The outputs from the last layer of the network should not be normalized.

# %% [markdown]
# # Batchnorm for deep networks
# Run the following to train a six-layer network on a subset of 1000 training examples both with and without batch normalization.

# %%
from implementations.fc_net import FullyConnectedNet

np.random.seed(15009)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000

X_train = data['X_train'][:num_train]
X_train = np.reshape(X_train, [X_train.shape[0], -1])
y_train = data['y_train'][:num_train]
                               
X_val = data['X_val']
X_val = np.reshape(X_val, [X_val.shape[0], -1])
y_val = data['y_val']


bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

# use an aggresive learning rate
bn_trace = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=5e-4,
                          reg=np.float32(0.01), 
                          keep_prob=0.5,
                          num_iters=800,
                          batch_size=100, 
                          verbose=True) # train the model with batch normalization
# Out:
# iteration 0 / 800: objective 232.401871
# iteration 100 / 800: objective 55.753826
# iteration 200 / 800: objective 5.179530
# iteration 300 / 800: objective 3.748473
# iteration 400 / 800: objective 3.305898
# iteration 500 / 800: objective 3.085577
# iteration 600 / 800: objective 2.952408
# iteration 700 / 800: objective 2.862734

# %% [markdown]
# Train a fully connected network without batch normalization

# %%
model = FullyConnectedNet(input_size=X_train.shape[1], 
                          hidden_size=hidden_dims, 
                          output_size=10, 
                          centering_data=True, 
                          use_dropout=False, 
                          use_bn=False)

# use an aggresive learning rate
baseline_trace = model.train(X_train, y_train, X_val, y_val,
                            learning_rate=5e-4,
                            reg=np.float32(0.01), 
                            num_iters=800,
                            batch_size=100, 
                            verbose=True) # train the model without batch normalization
# Out:
# iteration 0 / 800: objective 232.582138
# iteration 100 / 800: objective 208.176529
# iteration 200 / 800: objective 150.137131
# iteration 300 / 800: objective 98.864799
# iteration 400 / 800: objective 67.302826
# iteration 500 / 800: objective 73.101089
# iteration 600 / 800: objective 88.688469
# iteration 700 / 800: objective 51.870529

# %% [markdown]
# Run the following to visualize the results from two networks trained above. You should find that using batch normalization helps the network to converge much faster.

# %%
def plot_training_history(title, label, bl_plot, bn_plots, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    num_bn = len(bn_plots)
    
    for i in range(num_bn):
        label='batch normalization'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
        
    label='baseline'
    if labels is not None:
        label += str(labels[0])
        
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', baseline_trace['objective_history'], \
                      [bn_trace['objective_history']], bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', baseline_trace['train_acc_history'], \
                      [bn_trace['train_acc_history']], bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', baseline_trace['val_acc_history'], \
                      [bn_trace['val_acc_history']], bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Batch normalization and initialization
# We will now run a small experiment to study the interaction of batch normalization and weight initialization.
#
# The first cell will train 8-layer networks both with and without batch normalization using different scales for weight initialization. The second cell will plot training accuracy, validation set accuracy, and training loss as a function of the weight initialization scale.
#
# LIPING: I tried multiple configurations, but I did not find significant improvement from batch normalization. See if you can get clear improvement with your configurations.

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [50, 50, 50, 50, 50, 50, 50]
num_train = 10000

X_train = data['X_train'][:num_train]
X_train = np.reshape(X_train, [X_train.shape[0], -1])
y_train = data['y_train'][:num_train]
                               
X_val = data['X_val']
X_val = np.reshape(X_val, [X_val.shape[0], -1])
y_val = data['y_val']

bn_net_ws = {}
baseline_ws = {}

weight_scales = np.logspace(-4, 0, num=20)
for i, weight_scale in enumerate(weight_scales):
  print('Running weight scale=%f at round %d / %d' % (weight_scale, i + 1, len(weight_scales)))


  bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

  # use an aggresive learning rate
  bn_net_ws[weight_scale] = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=1e-2,
                          reg=np.float32(1e-5), 
                          keep_prob=0.5,
                          num_iters=1000,
                          batch_size=100, 
                          verbose=True) # train the model with batch normalization


  model = FullyConnectedNet(input_size=X_train.shape[1], 
                          hidden_size=hidden_dims, 
                          output_size=10, 
                          centering_data=True, 
                          use_dropout=False, 
                          use_bn=True)

  # use an aggresive learning rate
  baseline_ws[weight_scale] = model.train(X_train, y_train, X_val, y_val,
                            learning_rate=1e-2,
                            reg=np.float32(1e-5), 
                            num_iters=1000,
                            batch_size=100, 
                            verbose=True)
# Out:
# Running weight scale=0.000100 at round 1 / 20
# iteration 0 / 1000: objective 233.264023
# iteration 100 / 1000: objective 211.207596
# iteration 200 / 1000: objective 199.954575
# iteration 300 / 1000: objective 190.112030
# iteration 400 / 1000: objective 179.674500
# iteration 500 / 1000: objective 178.544388
# iteration 600 / 1000: objective 173.236313
# iteration 700 / 1000: objective 167.083710
# iteration 800 / 1000: objective 169.094696
# iteration 900 / 1000: objective 158.167480
# iteration 0 / 1000: objective 230.681122
# iteration 100 / 1000: objective 211.796661
# iteration 200 / 1000: objective 191.545929
# iteration 300 / 1000: objective 174.012695
# iteration 400 / 1000: objective 167.536346
# iteration 500 / 1000: objective 167.788559
# iteration 600 / 1000: objective 165.641037
# iteration 700 / 1000: objective 153.414429
# iteration 800 / 1000: objective 143.941711
# iteration 900 / 1000: objective 136.764145
# Running weight scale=0.000162 at round 2 / 20
# iteration 0 / 1000: objective 231.260742
# iteration 100 / 1000: objective 208.694214
# iteration 200 / 1000: objective 201.335373
# iteration 300 / 1000: objective 185.367325
# iteration 400 / 1000: objective 186.485107
# iteration 500 / 1000: objective 177.849854
# iteration 600 / 1000: objective 168.320816
# iteration 700 / 1000: objective 163.949387
# iteration 800 / 1000: objective 156.672958
# iteration 900 / 1000: objective 151.936203
# iteration 0 / 1000: objective 234.781433
# iteration 100 / 1000: objective 211.058807
# iteration 200 / 1000: objective 199.820938
# iteration 300 / 1000: objective 187.338974
# iteration 400 / 1000: objective 184.144760
# iteration 500 / 1000: objective 169.744247
# iteration 600 / 1000: objective 169.448227
# iteration 700 / 1000: objective 167.234344
# iteration 800 / 1000: objective 160.633301
# iteration 900 / 1000: objective 158.979797
# Running weight scale=0.000264 at round 3 / 20
# iteration 0 / 1000: objective 228.877167
# iteration 100 / 1000: objective 213.089600
# iteration 200 / 1000: objective 199.858597
# iteration 300 / 1000: objective 195.069275
# iteration 400 / 1000: objective 178.309555
# iteration 500 / 1000: objective 167.594711
# iteration 600 / 1000: objective 159.076218
# iteration 700 / 1000: objective 163.879028
# iteration 800 / 1000: objective 151.939270
# iteration 900 / 1000: objective 146.644775
# iteration 0 / 1000: objective 228.928604
# iteration 100 / 1000: objective 222.726288
# iteration 200 / 1000: objective 197.658615
# iteration 300 / 1000: objective 188.721970
# iteration 400 / 1000: objective 178.051926
# iteration 500 / 1000: objective 170.654709
# iteration 600 / 1000: objective 169.217010
# iteration 700 / 1000: objective 167.299072
# iteration 800 / 1000: objective 156.998154
# iteration 900 / 1000: objective 159.922806
# Running weight scale=0.000428 at round 4 / 20
# iteration 0 / 1000: objective 230.567474
# iteration 100 / 1000: objective 207.699402
# iteration 200 / 1000: objective 196.695206
# iteration 300 / 1000: objective 196.519913
# iteration 400 / 1000: objective 176.197098
# iteration 500 / 1000: objective 164.277985
# iteration 600 / 1000: objective 156.073593
# iteration 700 / 1000: objective 146.807983
# iteration 800 / 1000: objective 147.319290
# iteration 900 / 1000: objective 140.598022
# iteration 0 / 1000: objective 230.395493
# iteration 100 / 1000: objective 216.880371
# iteration 200 / 1000: objective 206.877563
# iteration 300 / 1000: objective 205.270935
# iteration 400 / 1000: objective 188.850952
# iteration 500 / 1000: objective 179.055954
# iteration 600 / 1000: objective 167.220184
# iteration 700 / 1000: objective 158.543427
# iteration 800 / 1000: objective 154.407867
# iteration 900 / 1000: objective 151.094101
# Running weight scale=0.000695 at round 5 / 20
# iteration 0 / 1000: objective 231.707062
# iteration 100 / 1000: objective 203.195816
# iteration 200 / 1000: objective 197.294540
# iteration 300 / 1000: objective 193.114349
# iteration 400 / 1000: objective 180.029221
# iteration 500 / 1000: objective 184.196671
# iteration 600 / 1000: objective 159.093918
# iteration 700 / 1000: objective 159.992065
# iteration 800 / 1000: objective 151.848221
# iteration 900 / 1000: objective 147.418304
# iteration 0 / 1000: objective 230.546356
# iteration 100 / 1000: objective 204.401001
# iteration 200 / 1000: objective 192.106842
# iteration 300 / 1000: objective 186.103561
# iteration 400 / 1000: objective 182.892319
# iteration 500 / 1000: objective 164.297516
# iteration 600 / 1000: objective 161.922272
# iteration 700 / 1000: objective 150.005188
# iteration 800 / 1000: objective 154.276474
# iteration 900 / 1000: objective 148.879807
# Running weight scale=0.001129 at round 6 / 20
# iteration 0 / 1000: objective 231.151199
# iteration 100 / 1000: objective 212.794235
# iteration 200 / 1000: objective 194.916321
# iteration 300 / 1000: objective 188.126038
# iteration 400 / 1000: objective 177.113373
# iteration 500 / 1000: objective 174.966644
# iteration 600 / 1000: objective 167.152328
# iteration 700 / 1000: objective 155.913574
# iteration 800 / 1000: objective 153.047134
# iteration 900 / 1000: objective 144.761841
# iteration 0 / 1000: objective 230.610336
# iteration 100 / 1000: objective 208.613770
# iteration 200 / 1000: objective 203.141525
# iteration 300 / 1000: objective 193.505035
# iteration 400 / 1000: objective 182.317810
# iteration 500 / 1000: objective 182.050156
# iteration 600 / 1000: objective 177.285446
# iteration 700 / 1000: objective 174.950195
# iteration 800 / 1000: objective 164.191086
# iteration 900 / 1000: objective 154.045105
# Running weight scale=0.001833 at round 7 / 20
# iteration 0 / 1000: objective 232.718445
# iteration 100 / 1000: objective 212.079147
# iteration 200 / 1000: objective 203.023880
# iteration 300 / 1000: objective 193.961868
# iteration 400 / 1000: objective 183.745377
# iteration 500 / 1000: objective 178.794922
# iteration 600 / 1000: objective 166.877579
# iteration 700 / 1000: objective 156.839539
# iteration 800 / 1000: objective 151.091980
# iteration 900 / 1000: objective 148.620285
# iteration 0 / 1000: objective 230.217636
# iteration 100 / 1000: objective 210.529510
# iteration 200 / 1000: objective 206.526443
# iteration 300 / 1000: objective 199.428085
# iteration 400 / 1000: objective 194.926270
# iteration 500 / 1000: objective 190.884613
# iteration 600 / 1000: objective 175.443192
# iteration 700 / 1000: objective 164.017960
# iteration 800 / 1000: objective 160.902115
# iteration 900 / 1000: objective 158.423920
# Running weight scale=0.002976 at round 8 / 20
# iteration 0 / 1000: objective 231.873917
# iteration 100 / 1000: objective 210.611404
# iteration 200 / 1000: objective 204.478546
# iteration 300 / 1000: objective 196.030365
# iteration 400 / 1000: objective 195.613663
# iteration 500 / 1000: objective 185.619522
# iteration 600 / 1000: objective 178.676331
# iteration 700 / 1000: objective 174.317932
# iteration 800 / 1000: objective 165.056976
# iteration 900 / 1000: objective 158.256531
# iteration 0 / 1000: objective 230.615799
# iteration 100 / 1000: objective 208.161041
# iteration 200 / 1000: objective 200.635101
# iteration 300 / 1000: objective 194.508575
# iteration 400 / 1000: objective 181.442215
# iteration 500 / 1000: objective 167.861893
# iteration 600 / 1000: objective 170.962433
# iteration 700 / 1000: objective 160.217499
# iteration 800 / 1000: objective 158.327744
# iteration 900 / 1000: objective 156.156342
# Running weight scale=0.004833 at round 9 / 20
# iteration 0 / 1000: objective 230.441269
# iteration 100 / 1000: objective 213.799469
# iteration 200 / 1000: objective 199.068893
# iteration 300 / 1000: objective 184.565735
# iteration 400 / 1000: objective 181.180847
# iteration 500 / 1000: objective 166.517670
# iteration 600 / 1000: objective 161.189056
# iteration 700 / 1000: objective 148.667252
# iteration 800 / 1000: objective 143.067307
# iteration 900 / 1000: objective 138.307632
# iteration 0 / 1000: objective 229.359543
# iteration 100 / 1000: objective 206.352692
# iteration 200 / 1000: objective 197.450134
# iteration 300 / 1000: objective 187.334518
# iteration 400 / 1000: objective 183.220520
# iteration 500 / 1000: objective 169.480942
# iteration 600 / 1000: objective 165.611710
# iteration 700 / 1000: objective 160.556137
# iteration 800 / 1000: objective 145.000214
# iteration 900 / 1000: objective 153.981644
# Running weight scale=0.007848 at round 10 / 20
# iteration 0 / 1000: objective 230.837814
# iteration 100 / 1000: objective 217.387543
# iteration 200 / 1000: objective 207.086960
# iteration 300 / 1000: objective 197.771423
# iteration 400 / 1000: objective 189.042496
# iteration 500 / 1000: objective 186.566071
# iteration 600 / 1000: objective 177.334808
# iteration 700 / 1000: objective 166.824860
# iteration 800 / 1000: objective 158.480667
# iteration 900 / 1000: objective 154.472183
# iteration 0 / 1000: objective 232.492584
# iteration 100 / 1000: objective 213.571976
# iteration 200 / 1000: objective 200.311707
# iteration 300 / 1000: objective 193.845016
# iteration 400 / 1000: objective 186.848221
# iteration 500 / 1000: objective 178.165894
# iteration 600 / 1000: objective 160.921661
# iteration 700 / 1000: objective 155.297195
# iteration 800 / 1000: objective 149.999481
# iteration 900 / 1000: objective 141.826996
# Running weight scale=0.012743 at round 11 / 20
# iteration 0 / 1000: objective 232.334518
# iteration 100 / 1000: objective 207.473557
# iteration 200 / 1000: objective 200.795609
# iteration 300 / 1000: objective 191.426117
# iteration 400 / 1000: objective 187.181335
# iteration 500 / 1000: objective 172.492691
# iteration 600 / 1000: objective 167.939774
# iteration 700 / 1000: objective 170.669342
# iteration 800 / 1000: objective 154.889511
# iteration 900 / 1000: objective 149.105438
# iteration 0 / 1000: objective 231.482529
# iteration 100 / 1000: objective 212.750961
# iteration 200 / 1000: objective 204.203659
# iteration 300 / 1000: objective 191.036255
# iteration 400 / 1000: objective 171.665741
# iteration 500 / 1000: objective 164.110596
# iteration 600 / 1000: objective 158.858627
# iteration 700 / 1000: objective 148.300034
# iteration 800 / 1000: objective 147.307587
# iteration 900 / 1000: objective 144.774887
# Running weight scale=0.020691 at round 12 / 20
# iteration 0 / 1000: objective 231.135269
# iteration 100 / 1000: objective 211.279739
# iteration 200 / 1000: objective 195.871597
# iteration 300 / 1000: objective 192.273560
# iteration 400 / 1000: objective 187.814484
# iteration 500 / 1000: objective 182.137222
# iteration 600 / 1000: objective 170.018723
# iteration 700 / 1000: objective 163.343842
# iteration 800 / 1000: objective 166.385574
# iteration 900 / 1000: objective 152.803528
# iteration 0 / 1000: objective 230.970459
# iteration 100 / 1000: objective 206.266403
# iteration 200 / 1000: objective 197.226913
# iteration 300 / 1000: objective 181.023605
# iteration 400 / 1000: objective 177.909027
# iteration 500 / 1000: objective 174.765533
# iteration 600 / 1000: objective 169.834351
# iteration 700 / 1000: objective 161.063202
# iteration 800 / 1000: objective 155.298904
# iteration 900 / 1000: objective 145.439682
# Running weight scale=0.033598 at round 13 / 20
# iteration 0 / 1000: objective 230.865112
# iteration 100 / 1000: objective 222.916245
# iteration 200 / 1000: objective 204.873077
# iteration 300 / 1000: objective 194.097519
# iteration 400 / 1000: objective 184.177505
# iteration 500 / 1000: objective 176.797928
# iteration 600 / 1000: objective 170.167953
# iteration 700 / 1000: objective 167.159607
# iteration 800 / 1000: objective 148.993942
# iteration 900 / 1000: objective 152.788986
# iteration 0 / 1000: objective 229.922760
# iteration 100 / 1000: objective 214.039703
# iteration 200 / 1000: objective 199.844620
# iteration 300 / 1000: objective 195.571930
# iteration 400 / 1000: objective 179.315475
# iteration 500 / 1000: objective 176.057465
# iteration 600 / 1000: objective 169.005356
# iteration 700 / 1000: objective 159.214417
# iteration 800 / 1000: objective 148.346924
# iteration 900 / 1000: objective 142.779419
# Running weight scale=0.054556 at round 14 / 20
# iteration 0 / 1000: objective 230.669678
# iteration 100 / 1000: objective 207.584091
# iteration 200 / 1000: objective 198.544861
# iteration 300 / 1000: objective 204.581848
# iteration 400 / 1000: objective 185.621780
# iteration 500 / 1000: objective 183.905243
# iteration 600 / 1000: objective 176.722229
# iteration 700 / 1000: objective 170.266891
# iteration 800 / 1000: objective 172.092957
# iteration 900 / 1000: objective 165.010040
# iteration 0 / 1000: objective 231.713501
# iteration 100 / 1000: objective 210.100052
# iteration 200 / 1000: objective 202.428558
# iteration 300 / 1000: objective 196.776016
# iteration 400 / 1000: objective 181.398682
# iteration 500 / 1000: objective 175.891571
# iteration 600 / 1000: objective 172.087479
# iteration 700 / 1000: objective 158.436356
# iteration 800 / 1000: objective 154.618454
# iteration 900 / 1000: objective 148.907135
# Running weight scale=0.088587 at round 15 / 20
# iteration 0 / 1000: objective 229.297882
# iteration 100 / 1000: objective 203.850906
# iteration 200 / 1000: objective 202.104874
# iteration 300 / 1000: objective 199.057144
# iteration 400 / 1000: objective 190.006638
# iteration 500 / 1000: objective 182.795166
# iteration 600 / 1000: objective 178.672470
# iteration 700 / 1000: objective 167.900497
# iteration 800 / 1000: objective 160.557220
# iteration 900 / 1000: objective 156.083389
# iteration 0 / 1000: objective 230.095032
# iteration 100 / 1000: objective 211.754272
# iteration 200 / 1000: objective 197.330887
# iteration 300 / 1000: objective 188.276627
# iteration 400 / 1000: objective 183.513077
# iteration 500 / 1000: objective 171.129410
# iteration 600 / 1000: objective 162.087097
# iteration 700 / 1000: objective 153.289185
# iteration 800 / 1000: objective 158.506744
# iteration 900 / 1000: objective 146.587738
# Running weight scale=0.143845 at round 16 / 20
# iteration 0 / 1000: objective 230.327438
# iteration 100 / 1000: objective 211.730453
# iteration 200 / 1000: objective 205.254822
# iteration 300 / 1000: objective 195.789627
# iteration 400 / 1000: objective 181.224411
# iteration 500 / 1000: objective 175.009415
# iteration 600 / 1000: objective 170.511078
# iteration 700 / 1000: objective 164.451447
# iteration 800 / 1000: objective 156.518845
# iteration 900 / 1000: objective 153.773102
# iteration 0 / 1000: objective 229.103989
# iteration 100 / 1000: objective 217.568008
# iteration 200 / 1000: objective 202.616730
# iteration 300 / 1000: objective 192.079712
# iteration 400 / 1000: objective 183.449280
# iteration 500 / 1000: objective 176.126114
# iteration 600 / 1000: objective 170.630447
# iteration 700 / 1000: objective 160.632019
# iteration 800 / 1000: objective 153.408295
# iteration 900 / 1000: objective 142.974838
# Running weight scale=0.233572 at round 17 / 20
# iteration 0 / 1000: objective 232.184570
# iteration 100 / 1000: objective 209.909531
# iteration 200 / 1000: objective 187.957306
# iteration 300 / 1000: objective 184.037827
# iteration 400 / 1000: objective 170.449844
# iteration 500 / 1000: objective 160.572845
# iteration 600 / 1000: objective 147.509277
# iteration 700 / 1000: objective 149.248688
# iteration 800 / 1000: objective 142.916565
# iteration 900 / 1000: objective 143.897369
# iteration 0 / 1000: objective 230.133118
# iteration 100 / 1000: objective 216.615448
# iteration 200 / 1000: objective 207.432892
# iteration 300 / 1000: objective 205.358994
# iteration 400 / 1000: objective 192.353821
# iteration 500 / 1000: objective 185.267838
# iteration 600 / 1000: objective 162.473892
# iteration 700 / 1000: objective 153.781509
# iteration 800 / 1000: objective 147.902359
# iteration 900 / 1000: objective 145.759201
# Running weight scale=0.379269 at round 18 / 20
# iteration 0 / 1000: objective 231.322205
# iteration 100 / 1000: objective 212.244141
# iteration 200 / 1000: objective 201.469559
# iteration 300 / 1000: objective 197.768982
# iteration 400 / 1000: objective 190.223679
# iteration 500 / 1000: objective 173.814651
# iteration 600 / 1000: objective 167.600204
# iteration 700 / 1000: objective 156.964142
# iteration 800 / 1000: objective 152.520630
# iteration 900 / 1000: objective 141.320282
# iteration 0 / 1000: objective 229.841156
# iteration 100 / 1000: objective 209.568985
# iteration 200 / 1000: objective 202.899567
# iteration 300 / 1000: objective 190.640228
# iteration 400 / 1000: objective 181.648895
# iteration 500 / 1000: objective 171.912262
# iteration 600 / 1000: objective 160.141800
# iteration 700 / 1000: objective 155.328613
# iteration 800 / 1000: objective 149.028946
# iteration 900 / 1000: objective 149.960754
# Running weight scale=0.615848 at round 19 / 20
# iteration 0 / 1000: objective 230.026535
# iteration 100 / 1000: objective 208.066376
# iteration 200 / 1000: objective 199.183212
# iteration 300 / 1000: objective 190.379974
# iteration 400 / 1000: objective 182.617157
# iteration 500 / 1000: objective 176.838257
# iteration 600 / 1000: objective 169.730621
# iteration 700 / 1000: objective 162.181000
# iteration 800 / 1000: objective 163.732925
# iteration 900 / 1000: objective 150.027695
# iteration 0 / 1000: objective 229.334503
# iteration 100 / 1000: objective 205.554352
# iteration 200 / 1000: objective 199.406769
# iteration 300 / 1000: objective 191.597122
# iteration 400 / 1000: objective 179.441681
# iteration 500 / 1000: objective 163.710419
# iteration 600 / 1000: objective 167.324799
# iteration 700 / 1000: objective 166.675934
# iteration 800 / 1000: objective 152.788132
# iteration 900 / 1000: objective 150.414932
# Running weight scale=1.000000 at round 20 / 20
# iteration 0 / 1000: objective 229.737045
# iteration 100 / 1000: objective 213.498703
# iteration 200 / 1000: objective 210.087936
# iteration 300 / 1000: objective 190.804016
# iteration 400 / 1000: objective 180.728226
# iteration 500 / 1000: objective 179.902969
# iteration 600 / 1000: objective 169.407074
# iteration 700 / 1000: objective 167.530563
# iteration 800 / 1000: objective 165.771744
# iteration 900 / 1000: objective 157.852600
# iteration 0 / 1000: objective 230.106339
# iteration 100 / 1000: objective 215.817932
# iteration 200 / 1000: objective 197.596558
# iteration 300 / 1000: objective 197.432297
# iteration 400 / 1000: objective 190.027725
# iteration 500 / 1000: objective 179.090164
# iteration 600 / 1000: objective 175.924438
# iteration 700 / 1000: objective 167.533356
# iteration 800 / 1000: objective 164.231232
# iteration 900 / 1000: objective 153.534088

# %%
# Plot results of weight scale experiment
best_train_accs, bn_best_train_accs = [], []
best_val_accs, bn_best_val_accs = [], []
final_train_loss, bn_final_train_loss = [], []

for ws in weight_scales:
  best_train_accs.append(max(baseline_ws[ws]['train_acc_history']))
  bn_best_train_accs.append(max(bn_net_ws[ws]['train_acc_history']))
  
  best_val_accs.append(max(baseline_ws[ws]['val_acc_history']))
  bn_best_val_accs.append(max(bn_net_ws[ws]['val_acc_history']))
  
  final_train_loss.append(np.mean(baseline_ws[ws]['objective_history'][-100:]))
  bn_final_train_loss.append(np.mean(bn_net_ws[ws]['objective_history'][-100:]))
  
plt.subplot(3, 1, 1)
plt.title('Best val accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best val accuracy')
plt.semilogx(weight_scales, best_val_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_val_accs, '-o', label='batchnorm')
plt.legend(ncol=2, loc='lower right')

plt.subplot(3, 1, 2)
plt.title('Best train accuracy vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Best training accuracy')
plt.semilogx(weight_scales, best_train_accs, '-o', label='baseline')
plt.semilogx(weight_scales, bn_best_train_accs, '-o', label='batchnorm')
plt.legend()

plt.subplot(3, 1, 3)
plt.title('Final training loss vs weight initialization scale')
plt.xlabel('Weight initialization scale')
plt.ylabel('Final training loss')
plt.semilogx(weight_scales, final_train_loss, '-o', label='baseline')
plt.semilogx(weight_scales, bn_final_train_loss, '-o', label='batchnorm')
plt.legend()
plt.gca().set_ylim(120, 160)

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Inline Question 1:
# Describe the results of this experiment. How does the scale of weight initialization affect models with/without batch normalization differently, and why?

# %% [markdown]
# ## Answer:
# with batch_normalization, for small weights, the accuracy is higher than without bn. But for high weight scale, the accuracy is decreasing with batch normalization. Because, regardless of the initial w, the gradient is not killed at the beginning, it starts high and then plods along as the iterations progress. Without BN, a small w can kill the gradient going backwards.
# BN performance is not actually decreasing for higher initial weights. It just that it takes longer to arrive at the desired ideal weights, because we're starting from further away.

# %% [markdown]
# # Batch normalization and batch size
# We will now run a small experiment to study the interaction of batch normalization and batch size.
#
# The first cell will train 6-layer networks both with and without batch normalization using different batch sizes. The second cell will plot training accuracy and validation set accuracy over time.
#
# Here is a link about batch sizes in batch normalization:
# https://www.graphcore.ai/posts/revisiting-small-batch-training-for-deep-neural-networks

# %%
def run_batchsize_experiments():
    np.random.seed(15009)
    # Try training a very deep net with batchnorm
    hidden_dims = [50, 50, 50, 50, 50]
    
    num_train = 1000

    X_train = data['X_train'][:num_train]
    X_train = np.reshape(X_train, [X_train.shape[0], -1])
    y_train = data['y_train'][:num_train]
                               
    X_val = data['X_val']
    X_val = np.reshape(X_val, [X_val.shape[0], -1])
    y_val = data['y_val']
    
    num_epochs = 10
    batch_sizes = [5,10,50]
    

    batch_size = batch_sizes[0]
    print('No normalization: batch size = ', 5)    
    baseline = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10,
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=False)

    # use an aggresive learning rate
    baseline_trace = baseline.train(X_train, y_train, X_val, y_val,
                                    learning_rate=10**-3,
                                    reg=np.float32(1e-5), 
                                    num_iters=num_train * num_epochs // batch_size ,
                                    batch_size=batch_size, 
                                    verbose=True) # train the model with batch normalization

    
    
    

    bn_traces = []
    for i in range(len(batch_sizes)):
        
        batch_size = batch_sizes[i]
        print('Normalization: batch size = ',batch_size)

    
        bn_model = FullyConnectedNet(input_size=X_train.shape[1], 
                             hidden_size=hidden_dims, 
                             output_size=10, 
                             centering_data=True, 
                             use_dropout=False, 
                             use_bn=True)

        # use an aggresive learning rate
        bn_net_trace = bn_model.train(X_train, y_train, X_val, y_val,
                          learning_rate=10**-3,
                          reg=np.float32(1e-5), 
                          num_iters=num_train * num_epochs // batch_size ,
                          batch_size=batch_size, 
                          verbose=True) # train the model with batch normalization

    
        bn_traces.append(bn_net_trace)
        
    return bn_traces, baseline_trace, batch_sizes

batch_sizes = [5,10,50]
bn_traces, baseline_trace, batch_sizes = run_batchsize_experiments()
# Out:
# No normalization: batch size =  5
# iteration 0 / 2000: objective 11.514305
# iteration 100 / 2000: objective 11.530845
# iteration 200 / 2000: objective 11.489232
# iteration 300 / 2000: objective 11.541492
# iteration 400 / 2000: objective 11.467241
# iteration 500 / 2000: objective 11.549950
# iteration 600 / 2000: objective 11.446713
# iteration 700 / 2000: objective 11.555372
# iteration 800 / 2000: objective 11.426663
# iteration 900 / 2000: objective 11.555120
# iteration 1000 / 2000: objective 11.404947
# iteration 1100 / 2000: objective 11.544064
# iteration 1200 / 2000: objective 11.375858
# iteration 1300 / 2000: objective 11.504647
# iteration 1400 / 2000: objective 11.316720
# iteration 1500 / 2000: objective 11.314795
# iteration 1600 / 2000: objective 11.028092
# iteration 1700 / 2000: objective 9.682540
# iteration 1800 / 2000: objective 10.528839
# iteration 1900 / 2000: objective 9.623592
# Normalization: batch size =  5
# iteration 0 / 2000: objective 11.149387
# iteration 100 / 2000: objective 11.270443
# iteration 200 / 2000: objective 10.392738
# iteration 300 / 2000: objective 10.556306
# iteration 400 / 2000: objective 9.845490
# iteration 500 / 2000: objective 10.593585
# iteration 600 / 2000: objective 9.736266
# iteration 700 / 2000: objective 10.558742
# iteration 800 / 2000: objective 9.321570
# iteration 900 / 2000: objective 10.197411
# iteration 1000 / 2000: objective 9.405167
# iteration 1100 / 2000: objective 10.501812
# iteration 1200 / 2000: objective 8.763936
# iteration 1300 / 2000: objective 10.638699
# iteration 1400 / 2000: objective 8.700446
# iteration 1500 / 2000: objective 10.314815
# iteration 1600 / 2000: objective 8.966275
# iteration 1700 / 2000: objective 10.301723
# iteration 1800 / 2000: objective 8.519549
# iteration 1900 / 2000: objective 9.637174
# Normalization: batch size =  10
# iteration 0 / 1000: objective 22.845301
# iteration 100 / 1000: objective 21.764366
# iteration 200 / 1000: objective 19.794355
# iteration 300 / 1000: objective 17.274643
# iteration 400 / 1000: objective 15.608751
# iteration 500 / 1000: objective 16.079332
# iteration 600 / 1000: objective 13.499825
# iteration 700 / 1000: objective 13.242400
# iteration 800 / 1000: objective 13.048783
# iteration 900 / 1000: objective 11.966062
# Normalization: batch size =  50
# iteration 0 / 200: objective 115.275490
# iteration 100 / 200: objective 76.272095

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', 
                      baseline_trace['train_acc_history'], 
                      [trace['train_acc_history'] for trace in bn_traces],
                      bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', 
                      baseline_trace['val_acc_history'], 
                      [trace['val_acc_history'] for trace in bn_traces],
                      bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# ## Inline Question 2:
# Describe the results of this experiment. What does this imply about the relationship between batch normalization and batch size? Why is this relationship observed?
#
# ## Answer:
# for batch size 5 and 10 with bn have high train and valid accuracy, for batch size 50 with batch normalization has lower train and valid accuracy, and without batch normalization has lowest accuracy. With small batch size, the batch normalization performs better. because here we have more iterations to update the parameters.
